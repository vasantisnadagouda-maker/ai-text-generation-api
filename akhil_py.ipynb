# %% [markdown]
# <a href="https://colab.research.google.com/github/vasantisnadagouda-maker/ai-text-generation-api/blob/main/akhil_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

openai_key = os.getenv("OPENAI_API_KEY")
gemini_key = os.getenv("GEMINI_API_KEY")
